# %%
import pandas as pd
import numpy as np
import matplotlib
from config import gkey
import requests
import time
from us import states
import gmaps




# july 10 - Nov 30th 2018

# %%
cfile = 'Downloads/MPLS_CRIME_STATS1.csv'

#cfile = 'Documents/MPLS_CRIME_STATS2.csv'

cstats=pd.read_csv(cfile)

cstats=cstats.fillna(value=0)

cstats['neighborhood']=cstats['neighborhood'].str.upper()

#cstats.reset_index(inplace = True)
#Removing the data for 2019 because we don't have scooter data for 2019

#Code to exclude certain years(ie 2017 there was no scooters and 2018 there were)

cstats2 = cstats.loc[cstats['reportYear']==2018.0]
cstats2
# Out:
#        OBJECTID        neighborhood        Lat       Long      ucrDescription  \
# 1520       3521  ** NOT ASSIGNED **   0.000000   0.000000  Aggravated Assault
# 1521       3522  ** NOT ASSIGNED **   0.000000   0.000000               Arson
# 1522       3523  ** NOT ASSIGNED **   0.000000   0.000000          Auto Theft
# 1523       3524  ** NOT ASSIGNED **   0.000000   0.000000            Burglary
# 1524       3525  ** NOT ASSIGNED **   0.000000   0.000000            Homicide
# 1525       3526  ** NOT ASSIGNED **   0.000000   0.000000             Larceny
# 1526       3527  ** NOT ASSIGNED **   0.000000   0.000000                Rape
# 1527       3528  ** NOT ASSIGNED **   0.000000   0.000000             Robbery
# 1528       3529            ARMATAGE  44.898481 -93.311195  Aggravated Assault
# 1529       3530            ARMATAGE  44.898481 -93.311195               Arson
# 1530       3531            ARMATAGE  44.898481 -93.311195          Auto Theft
# ...

# %%
#lstats=cstats.loc[cstats[]]

# %%
print(cstats.iloc[[11969]])
# Out:
#        OBJECTID       neighborhood        Lat       Long ucrDescription  \
# 11969     13970  SUMNER - GLENWOOD  44.984204 -93.290894          Arson
#
#        number  reportMonth  reportYear
# 11969     0.0            3        2019

# %%
#nstats=cstats.groupby('neighborhood').agg({'number': 'sum','Lat':'first','Long':'first'})
nstats=cstats2.groupby('neighborhood').agg({'number': 'sum','Lat':'first','Long':'first'})

# %%
nstats.reset_index(inplace=True)

# %%
nstats['number'].sum()
# Out:
# 20332.0

# %%
#nstats.to_csv(r'\heat_layer.csv')

# %%
nstats
# Out:
#                         neighborhood  number        Lat       Long
# 0                 ** NOT ASSIGNED **    62.0   0.000000   0.000000
# 1                           ARMATAGE    88.0  44.898481 -93.311195
# 2                       AUDUBON PARK   174.0  45.017224 -93.237808
# 3                           BANCROFT    85.0  44.929271 -93.254591
# 4                           BELTRAMI    56.0  44.994943 -93.241600
# 5                          BOTTINEAU    88.0  45.008185 -93.268369
# 6                             BRYANT    81.0  44.931174 -93.269679
# 7                        BRYN - MAWR    60.0  44.973051 -93.313616
# 8                  CAMDEN INDUSTRIAL    15.0  45.035678 -93.286694
# 9                              CARAG   341.0  44.941056 -93.291062
# 10              CEDAR - ISLES - DEAN    74.0  44.954166 -93.321534
# 11                   CEDAR RIVERSIDE   357.0  44.966897 -93.243470
# 12                           CENTRAL   315.0  44.976463 -93.276112
# ...

# %%
locations = nstats[['Lat','Long']].astype(float)


crime_rate = nstats["number"].astype(float)

# %%
total_crime

print(total)
# Out:
# 40652.0

# %%
# Create Map of Minneapolis


# Configure gmaps with API key
gmaps.configure(api_key=gkey) 

fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=crime_rate, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = False
heat_layer.max_intensity = 1000
heat_layer.point_radius = 1

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
